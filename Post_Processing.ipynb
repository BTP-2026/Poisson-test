# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as tick
import matplotlib as mpl
import h5py
import os
from utils import get_train_data, read_h5_file

get_dir = os.getcwd()
os.chdir(get_dir)

# %%
def get_predictions_and_true_data_poisson(mdir, ddir, sen_dir, indices):
    # Load and sort sensor indices to preserve spatial order
    sen_ind = np.sort(pd.read_csv(sen_dir)["sensor_indices"].values.reshape(-1))

    # Load model and data
    model = tf.keras.models.load_model(mdir, safe_mode=False)
    f_all, xdisc, u_all, bc_all = read_h5_file(ddir)

    # Ensure coordinate shapes are consistent
    x_flat = np.asarray(xdisc).reshape(-1)                # (Nx,)
    x_col = x_flat.reshape(-1, 1).astype(np.float32)      # (Nx, 1)
    Nx = x_col.shape[0]
    x_left = x_flat[0:1]
    x_right = x_flat[-1:]
    xb = np.repeat(np.concatenate((x_left, x_right), axis=0), Nx / 2, axis=0 ).reshape(-1,1)  # (Nx, 1)
    seq_len = len(sen_ind)

    # Prepare repeated/sensor matrices with correct rank-3 shapes (batch, seq_len, 1)
    u_pred = []
    u_true = []
    f = []
    xs = []

    for i in indices:
        # Inputs per sample
        f_i = np.asarray(f_all[i]).reshape(-1, 1).astype(np.float32)  # (Nx, 1)
        fb = np.tile([f_all[i, 0], f_all[i, -1]], Nx // 2).reshape(-1, 1)
        u_sen = np.asarray(u_all[i, sen_ind]).reshape(1, seq_len, 1).astype(np.float32)  # (1, S, 1)
        x_sen = x_col[sen_ind].reshape(1, seq_len, 1).astype(np.float32)                 # (1, S, 1)

        # Repeat sensors across query points to match (batch=Nx, seq_len, 1)
        ubc = np.repeat(u_sen, Nx, axis=0)  # (Nx, S, 1)
        xbc = np.repeat(x_sen, Nx, axis=0)  # (Nx, S, 1)

        # Predict with correctly shaped tensors
        u_hat = model.predict([x_col, f_i, xbc, ubc]).reshape(-1)
        # Collect outputs
        xs.append(x_flat.copy())
        f.append(f_i.reshape(-1))
        u_pred.append(u_hat)
        u_true.append(np.asarray(u_all[i]).reshape(-1))

    return xs, f, u_pred, u_true

# %%
def plot_poisson_solutions(x, u_pred, u_true, f, indices, err, plot_save=False, plot_dir='poisson_results', fig_size=(15, 10)):
    n_samples = len(indices)
    
    # Create 2 rows: (solution, forcing)
    if n_samples == 1:
        fig, ax = plt.subplots(2, 1, figsize=fig_size, sharex=True)
        axes = np.array([[ax[0]], [ax[1]]])  # shape (2,1) for consistent indexing
    else:
        fig, axes = plt.subplots(2, n_samples, figsize=fig_size, sharex=True)
    
    for i in range(n_samples):
        xi = np.asarray(x[i]).reshape(-1)
        up = np.asarray(u_pred[i]).reshape(-1)
        ut = np.asarray(u_true[i]).reshape(-1)
        fi = np.asarray(f[i]).reshape(-1)

        # Solution p(x)
        axes[0, i].plot(xi, up, 'b-', label='PINTO Prediction', linewidth=2)
        axes[0, i].plot(xi, ut, 'r--', label='True Solution', linewidth=2)
        axes[0, i].set_title(f'Solution p(x) - Sample {indices[i]}')
        axes[0, i].set_ylabel('u(x)')
        axes[0, i].legend()
        axes[0, i].grid(True, alpha=0.3)

        # simple continuous relative error (scaled by max absolute true value to avoid blow-ups)
        denom = np.max(np.abs(ut))
        rel_err = np.abs(up - ut) / denom
        axes[1, i].plot(xi, rel_err, 'k-.', label='Relative error (scaled)', linewidth=1.5)

    
    plt.tight_layout()
    
    if plot_save:
        os.makedirs(plot_dir, exist_ok=True)
        plt.savefig(os.path.join(plot_dir, 'poisson_solutions.png'), dpi=300, bbox_inches='tight', format='png')
    
    plt.show()

# %%
# Set up paths and parameters
mdir = './output/Poisson_PINTO/Poisson_model.keras'  # Path to trained model
ddir = './data/poisson_1000.h5'  # Path to Poisson data
sen_dir = './output/Poisson_PINTO/sensor.csv'  # Path to sensor indices CSV

# Define sample indices for analysis
train_indices = [20]  # Seen boundary conditions
all_indices = train_indices

# Generate predictions
xs, f, u_pred, u_true = get_predictions_and_true_data_poisson(
    mdir, ddir, sen_dir=sen_dir, indices=all_indices 
)

plot_poisson_solutions(xs[:len(train_indices)], u_pred[:len(train_indices)], u_true[:len(train_indices)], f[:len(train_indices)], train_indices, [], plot_save=True, plot_dir='Poisson_Train_Results', fig_size=(16, 12))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
corr = np.corrcoef(u_pred, u_true)[0,1]
corr_rev = np.corrcoef(u_pred, u_true[::-1])[0,1]
print("corr:", corr, "corr(with x reversed):", corr_rev)
# Out:
# corr: 0.8102605701594866 corr(with x reversed): 0.8102605701594866

# %%
import numpy as np

u_pred = np.asarray(u_pred).flatten()
u_true = np.asarray(u_true).flatten()

def stats(u_pred, u_true):
    print("shapes:", u_pred.shape, u_true.shape)
    print("mean u_pred, mean u_true:", u_pred.mean(), u_true.mean())
    print("std u_pred, std u_true:", u_pred.std(), u_true.std())
    print("corr:", np.corrcoef(u_pred, u_true)[0,1])
    print("corr with reversed true:", np.corrcoef(u_pred, u_true[::-1])[0,1])
    print("corr with -true:", np.corrcoef(u_pred, -u_true)[0,1])
    print("mean product u_pred*u_true:", np.mean(u_pred * u_true))
    print("mean product u_pred*(-u_true):", np.mean(u_pred * (-u_true)))
    # simple linear fit u_pred ≈ a*u_true + b
    A = np.vstack([u_true, np.ones_like(u_true)]).T
    a, b = np.linalg.lstsq(A, u_pred, rcond=None)[0]
    print("least-squares fit: u_pred ≈ a*u_true + b  --> a=", a, " b=", b)
    recon = a*u_true + b
    print("max abs residual of fit:", np.max(np.abs(recon - u_pred)))

stats(u_pred, u_true)
# Out:
# shapes: (100,) (100,)
# mean u_pred, mean u_true: 0.09206207 0.082491582491582
# std u_pred, std u_true: 0.047505703 0.038014980364985705
# corr: 0.8102605701594866
# corr with reversed true: 0.8102605701594919
# corr with -true: -0.8102605701594866
# mean product u_pred*u_true: 0.00905761906936734
# mean product u_pred*(-u_true): -0.00905761906936734
# least-squares fit: u_pred ≈ a*u_true + b  --> a= 1.0125481615158054  b= 0.008535377823498055
# max abs residual of fit: 0.04784106448969622

# %%
import numpy as np
# u_pred, u_true, x already numpy arrays
def orientation_mse(u_pred, u_true):
    return np.mean((u_pred - u_true)**2)

mse_same = orientation_mse(u_pred, u_true)
mse_rev  = orientation_mse(u_pred, u_true[::-1])
mse_neg  = orientation_mse(u_pred, -u_true)
print("MSE same:", mse_same)
print("MSE reversed:", mse_rev)
print("MSE negated:", mse_neg)

# find index of maxima/minima to compare locations
print("idx max pred, idx max true, idx max true reversed:",
      np.argmax(u_pred), np.argmax(u_true), np.argmax(u_true[::-1]))
print("idx min pred, idx min true, idx min true reversed:",
      np.argmin(u_pred), np.argmin(u_true), np.argmin(u_true[::-1]))
# Out:
# MSE same: 0.0008669798577941273
# MSE reversed: 0.0008669798577941085
# MSE negated: 0.03709745613526349
# idx max pred, idx max true, idx max true reversed: 40 50 49
# idx min pred, idx min true, idx min true reversed: 99 0 0
